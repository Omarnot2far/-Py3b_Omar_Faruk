# %%
#Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#importing data 
df = pd.read_csv('A4_CC GENERAL.csv')
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
# Removing selected columns to simplify the dataset for clustering
df.drop(['CUST_ID','BALANCE_FREQUENCY', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES',
         'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 
         'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY', 
         'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'MINIMUM_PAYMENTS', 
         'PRC_FULL_PAYMENT'], axis=1, inplace=True)

# %% [markdown]
# By keeping columns like BALANCE, PURCHASES, CASH_ADVANCE, CREDIT_LIMIT, PAYMENTS, and TENURE, the dataset focuses on financial behaviors. These variables are likely to show patterns in customer behaviors, making them more suitable for clustering compared to frequencies or transaction counts.

# %%
df.head()
# Out:
#        BALANCE  PURCHASES  CASH_ADVANCE  CREDIT_LIMIT     PAYMENTS  TENURE
# 0    40.900749      95.40      0.000000        1000.0   201.802084      12
# 1  3202.467416       0.00   6442.945483        7000.0  4103.032597      12
# 2  2495.148862     773.17      0.000000        7500.0   622.066742      12
# 3  1666.670542    1499.00    205.788017        7500.0     0.000000      12
# 4   817.714335      16.00      0.000000        1200.0   678.334763      12

# %%
df.columns
# Out:
# Index(['BALANCE', 'PURCHASES', 'CASH_ADVANCE', 'CREDIT_LIMIT', 'PAYMENTS',
#        'TENURE'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BALANCE       8950 non-null   float64
#  1   PURCHASES     8950 non-null   float64
#  2   CASH_ADVANCE  8950 non-null   float64
#  3   CREDIT_LIMIT  8949 non-null   float64
#  4   PAYMENTS      8950 non-null   float64
#  5   TENURE        8950 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 419.7 KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8949 entries, 0 to 8949
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BALANCE       8949 non-null   float64
#  1   PURCHASES     8949 non-null   float64
#  2   CASH_ADVANCE  8949 non-null   float64
#  3   CREDIT_LIMIT  8949 non-null   float64
#  4   PAYMENTS      8949 non-null   float64
#  5   TENURE        8949 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 489.4 KB

# %%
X = df[['BALANCE', 'PURCHASES', 'CASH_ADVANCE', 'CREDIT_LIMIT', 'PAYMENTS',
       'TENURE']]

# %%
scaler = StandardScaler()

scaler.fit(X)

X_scaled = scaler.transform(X)

print("Shape of X_scaled:", X_scaled.shape)
print("Mean of each feature in X_scaled:", X_scaled.mean(axis=0))
print("Standard deviation of each feature in X_scaled:", X_scaled.std(axis=0))
# Out:
# Shape of X_scaled: (8949, 6)
# Mean of each feature in X_scaled: [ 0.00000000e+00 -8.25750861e-17 -1.58798242e-17  2.15965610e-16
#   6.35192970e-17 -2.79484907e-16]
# Standard deviation of each feature in X_scaled: [1. 1. 1. 1. 1. 1.]

# %%
pca = PCA(n_components=2)

pca.fit(X_scaled)

X_pca = pca.transform(X_scaled)

X_pca.shape
# Out:
# (8949, 2)

# %%
# Initialize a list to store the inertia values
inertia_values = []

# Try different values of k
k_values = range(1, 15)
for k in k_values:
    # Initialize K-means clustering algorithm
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=10)
    
    # Fit the model to the data
    kmeans.fit(X_pca)
    
    # Get the inertia (sum of squared distances to the nearest centroid)
    inertia_values.append(kmeans.inertia_)
    
# Plot the elbow curve
plt.plot(k_values, inertia_values, marker='o')
plt.title('Elbow Plot (Customer Segmentation)')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()
# Out:
# C:\Users\faruk\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\faruk\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\faruk\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\faruk\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\faruk\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
K = 4

# %%
kmeans = KMeans(n_clusters=K, random_state=0, n_init=10)

# %%
kmeans.fit(X_pca)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=0)

# %%
labels = kmeans.labels_
centers = kmeans.cluster_centers_

centers
# Out:
# array([[ 6.8820416 ,  4.52913507],
#        [-0.79366338,  0.02397184],
#        [ 3.16076655, -1.93391476],
#        [ 0.9256321 ,  0.33850693]])

# %%
# Plot the data with cluster assignments
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels)
plt.scatter(centers[:, 0], centers[:, 1], marker='x', color='red', label='Cluster Centers')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering on PCA Data')
plt.legend()
plt.show()

# %%
silhouette_avg = silhouette_score(X_pca, labels)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.46047045480394855

# %%
# Initialize a list to store the inertia values
sc_values = []
max_score = 0
max_score_k = 0

# Try different values of k
k_values = range(5, 15)
for k in k_values:
    # Initialize K-means clustering algorithm
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=10)
    
    # Fit the model to the data
    kmeans.fit(X_pca)
    labels = kmeans.labels_
    
    # Get the silhouette score
    sc_value = silhouette_score(X_pca, labels)
    sc_values.append(sc_value)
    
    # Save the highest value
    (max_score, max_score_k) = (sc_value, k) if sc_value > max_score else (max_score, max_score_k)
    
# Plot the elbow curve
plt.plot(k_values, sc_values, marker='o')
plt.title(f"optimal K: {max_score_k} with score: {max_score}")
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

# %%
kmeans = KMeans(n_clusters=10, random_state=0, n_init=10)

kmeans.fit(X_pca)

labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Define a list of distinct colors for the labels (0 to 9)
label_colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'purple', 'orange', 'brown']

# Map each label to its corresponding color
cluster_colors = [label_colors[label] for label in labels]

scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_colors)

# Create a custom color map for the colorbar
cmap = plt.cm.colors.ListedColormap(label_colors)
norm = plt.cm.colors.BoundaryNorm(np.arange(0, 11, 1), cmap.N)

# Create a colorbar with discrete colors
# cb = plt.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=norm), ticks=np.arange(0, 10, 1))

cb = plt.colorbar(scatter, cmap=cmap, norm=norm, ticks=np.arange(0, 10, 1))
cb.set_label("Cluster Labels")

plt.scatter(centers[:, 0], centers[:, 1], marker='x', color='red', label='Cluster Centers')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering on PCA Data')
plt.legend()
plt.show()

# %%
df["labels"] = labels # Add labels as new column
df["pca1"] = X_pca[:, 0]
df["pca2"] = X_pca[:, 1]
df
# Out:
#           BALANCE  PURCHASES  CASH_ADVANCE  CREDIT_LIMIT     PAYMENTS  TENURE  \
# 0       40.900749      95.40      0.000000        1000.0   201.802084      12
# 1     3202.467416       0.00   6442.945483        7000.0  4103.032597      12
# 2     2495.148862     773.17      0.000000        7500.0   622.066742      12
# 3     1666.670542    1499.00    205.788017        7500.0     0.000000      12
# 4      817.714335      16.00      0.000000        1200.0   678.334763      12
# ...           ...        ...           ...           ...          ...     ...
# 8945    28.493517     291.12      0.000000        1000.0   325.594462       6
# 8946    19.183215     300.00      0.000000        1000.0   275.861322       6
# 8947    23.398673     144.40      0.000000        1000.0    81.270775       6
# 8948    13.457564       0.00     36.558778         500.0    52.549959       6
# 8949   372.708075    1093.25    127.040008        1200.0    63.165404       6
#
#       labels      pca1      pca2
# 0          0 -1.368025  0.280435
# 1          9  1.984023 -1.709942
# 2          7  0.227126  0.141745
# 3          7  0.098208  0.376494
# 4          0 -1.100016  0.168890
# ...      ...       ...       ...
# 8945       3 -1.793825 -1.489141
# 8946       3 -1.803084 -1.488615
# 8947       3 -1.863188 -1.546085
# 8948       3 -1.954958 -1.599267
# 8949       3 -1.575564 -1.371849
#
# [8949 rows x 9 columns]

# %%
df[df["labels"] == 5]
# Out:
#            BALANCE  PURCHASES  CASH_ADVANCE  CREDIT_LIMIT     PAYMENTS  \
# 23     3800.151377    4248.35   7974.415626        9000.0  9479.043842
# 30    12136.219960    3038.01   3183.583301       13000.0  4230.323491
# 36     7427.076941       0.00   8873.375046        9000.0  1636.361601
# 50     4931.331857     901.42   8530.648614       12000.0  8113.297346
# 86     7069.950386    1603.78   5626.004046       11000.0  4589.873897
# ...            ...        ...           ...           ...          ...
# 8315   2648.244646       0.00  10458.978150        4000.0  9818.531412
# 8422   3911.628474       0.00  11951.903320        7000.0  7918.877416
# 8705   7302.672686       0.00  10762.707760        9000.0  3824.308564
# 8857   2330.222764    1320.00  14926.790590       10000.0  8157.666434
# 8941   5967.475270     214.55   8555.409326        9000.0   966.202912
#
#       TENURE  labels      pca1      pca2
# 23        12       5  4.341495 -0.658112
# 30        12       5  4.697158 -1.350115
# 36        11       5  3.117296 -3.510195
# 50         8       5  3.955492 -3.225147
# 86        12       5  3.579987 -1.599266
# ...      ...     ...       ...       ...
# 8315      12       5  3.208768 -2.341083
# 8422       8       5  3.508510 -4.288508
# 8705      12       5  3.902648 -3.550378
# 8857       7       5  4.296607 -4.756905
# 8941       6       5  2.256943 -4.706937
#
# [255 rows x 9 columns]
